# %%
#dtype_dict = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int}

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel("mesho.xlsx")

# %%
df.head()
# Out:
#   Order Related Details           Unnamed: 1                   Unnamed: 2  \
# 0          Sub Order No           Order Date                          SKU
# 1                   NaN                  NaN                          NaN
# 2        806152218988_1  2023-09-23 12:37:15  stampabcdwoodcapitalvintage
# 3        164143587500_1  2023-09-21 17:04:05            ART-MARK-ALC-12SK
# 4        386441478209_1  2023-09-20 20:38:44  stampabcdwoodcapitalvintage
#
#           Unnamed: 3     Unnamed: 4                              Unnamed: 5  \
# 0  Live Order Status  Product GST %  Listing Price (Incl. GST & Commission)
# 1                NaN              A                                     NaN
# 2          Delivered             18                                     239
# 3          Delivered             18                                     229
# 4          Delivered             18                                     239
#
#   Unnamed: 6  Payment Details    Unnamed: 8  \
# 0   Quantity   Transaction ID  Payment Date
# 1        NaN              NaN           NaN
# 2          1  YESB32764823640    2023-10-03
# 3          1  YESB32764823640    2023-10-03
# 4          1  YESB32764823640    2023-10-03
#
#                                           Unnamed: 9  ...  \
# 0                            Final Settlement Amount  ...
# 1  (B + C + D + E + G + H + I + L + M + N + O + P...  ...
# 2                                             233.74  ...
# 3                                              223.8  ...
# 4                                             233.74  ...
#
#                                          Unnamed: 35  \
# 0  GST on Shipping Charge', 'CGST + SGST on Shipp...
# 1                                       N = I * 0.18
# 2                                             -10.83
# 3                                              -11.9
# 4                                             -10.83
#
#                      Unnamed: 36                               Unnamed: 37  \
# 0  GST on Return Shipping Charge  GST on Net Other Support Service Charges
# 1                   O = H * 0.18                          P = L * 18 / 100
# 2                            0.0                                       0.0
# 3                            0.0                                       0.0
# 4                            0.0                                       0.0
#
#         Unnamed: 38                                    Unnamed: 39  \
# 0  GST on Fixed Fee                                            TCS
# 1    AE = AC * 0.18  Q = - 1% of (B + C + D + E + U + V) / (1 + A)
# 2              -0.0                                          -2.63
# 3              -0.0                                           -2.6
# 4              -0.0                                          -2.63
#
#   Unnamed: 40                                    Unnamed: 41  \
# 0  TDS Rate %                                            TDS
# 1           X  T = - X% of (B + C + D + E + U + V) / (1 + A)
# 2         1.0                                          -2.63
# 3         1.0                                           -2.6
# 4         1.0                                          -2.63
#
#   Recovery, Claims and Compensation Details Unnamed: 43 Unnamed: 44
# 0                              Compensation      Claims    Recovery
# 1                                         R           Y           S
# 2                                       0.0         0.0         0.0
# 3                                       0.0         0.0         0.0
# 4                                       0.0         0.0         0.0
#
# [5 rows x 45 columns]

# %%
df.columns
# Out:
# Index(['Order Related Details', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Payment Details',
#        'Unnamed: 8', 'Unnamed: 9', 'Revenue Details', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Marketplace Fee Deductions', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Other Charges', 'Unnamed: 29',
#        'Unnamed: 30', 'Tax Summary', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Recovery, Claims and Compensation Details', 'Unnamed: 43',
#        'Unnamed: 44'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
#
unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6   Payment Details  \
# count         281        282        281        281               281
# unique          6          4         86          4                35
# top     Delivered         18        129          1  IN6ON23102600UXL
# freq          228        257         19        269                38
#
#         Unnamed: 8 Unnamed: 9  ... Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# count          281        282  ...         282         282         282
# unique          19        159  ...          64          10           3
# top     2023-10-25        0.0  ...        -0.0         0.0         0.0
# freq            69         29  ...          44         262         280
#
#        Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41  \
# count          282         282         236         236
# unique           4         123           3         119
# top           -0.0        -0.0         1.0        -2.6
# freq           236          44         234           9
#
#        Recovery, Claims and Compensation Details Unnamed: 43 Unnamed: 44
# count                                        282         282         282
# unique                                         3           3           3
# top                                          0.0         0.0         0.0
# freq                                         280         280         280
#
# [4 rows x 45 columns]

# %%
df.columns
# Out:
# Index(['Order Related Details', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Payment Details',
#        'Unnamed: 8', 'Unnamed: 9', 'Revenue Details', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Marketplace Fee Deductions', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Other Charges', 'Unnamed: 29',
#        'Unnamed: 30', 'Tax Summary', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Recovery, Claims and Compensation Details', 'Unnamed: 43',
#        'Unnamed: 44'],
#       dtype='object')

# %%
df['Unnamed: 13']
# Out:
# 0      Fixed Fee (Incl. GST)
# 1                         AD
# 2                        0.0
# 3                        0.0
# 4                        0.0
#                ...
# 277                      0.0
# 278                      0.0
# 279                      0.0
# 280                      0.0
# 281                      0.0
# Name: Unnamed: 13, Length: 282, dtype: object

# %%
df=pd.read_excel("mesho.xlsx", skiprows=1)

# %%
df.columns
# Out:
# Index(['Sub Order No', 'Order Date', 'SKU', 'Live Order Status',
#        'Product GST %', 'Listing Price (Incl. GST & Commission)', 'Quantity',
#        'Transaction ID', 'Payment Date', 'Final Settlement Amount',
#        'Price Type', 'Total Sale Amount (Incl. Commission & GST)',
#        'Sale Return Amount (Incl. GST)', 'Fixed Fee (Incl. GST)',
#        'Waas fee (inc Gst)', 'Shipping Revenue (Incl. GST)',
#        'Shipping Return Amount (Incl. GST)', 'Return premium (incl GST)',
#        'Return premium (incl GST) of Return', 'Meesho Commission Percentage',
#        'Meesho Commission (Excl. GST)', 'Meesho gold platform fee (excl GST)',
#        'Meesho mall platform fee (excl. GST)', 'Fixed Fee (excl. GST)',
#        'Waas fee (excl Gst)', 'Return Shipping Charge (Excl. GST)',
#        'GST Compensation (PRP Shipping)', 'Shipping Charge (Excl. GST)',
#        'Other Support Service Charges (Excl. GST)', 'Waivers (Excl. GST)',
#        'Net Other Support Service Charges (Excl. GST)',
#        'GST on Meesho Commission', 'GST on Waas fee', 'GST on meesho gold',
#        'GST on Meesho Mall platform fee',
#        'GST on Shipping Charge', 'CGST + SGST on Shipping Charge',
#        'GST on Return Shipping Charge',
#        'GST on Net Other Support Service Charges', 'GST on Fixed Fee', 'TCS',
#        'TDS Rate %', 'TDS', 'Compensation', 'Claims', 'Recovery'],
#       dtype='object')
